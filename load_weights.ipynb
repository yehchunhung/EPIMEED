# %% [markdown]
# # Emotion Predictor

# %%
import time
import numpy as np
import tensorflow as tf
import h5py
from os import mkdir
from os.path import exists
from pytorch_transformers import RobertaTokenizer

from optimize import *
from model_utils import *
from model_emo_pred import EmotionPredictor, EmotionPredictorPlus, loss_function
from datasets import *


# Some hyper-parameters
num_layers = 12
d_model = 768
num_heads = 12
dff = d_model * 4
hidden_act = 'gelu'  # Use 'gelu' or 'relu'
dropout_rate = 0.1
layer_norm_eps = 1e-5
max_position_embed = 102
type_vocab_size = 2  # Segments

tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
vocab_size = tokenizer.vocab_size

num_emotions = 41
num_comms = 7
max_length = 100  # Maximum number of tokens
# Out:
# 2021-11-17 17:37:24.131255: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
# Define the model.
# # for meed2
# emotion_predictor = EmotionPredictor(num_layers, d_model, num_heads, dff, hidden_act,
#     dropout_rate, layer_norm_eps, max_position_embed, type_vocab_size, vocab_size, num_emotions)

# for meed2+
emotion_predictor = EmotionPredictorPlus(num_layers, d_model, num_heads, dff, hidden_act,
    dropout_rate, layer_norm_eps, max_position_embed, type_vocab_size, vocab_size, num_emotions, num_comms)
# Out:
# 2021-11-17 17:37:26.936822: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-11-17 17:37:27.107386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: TITAN X (Pascal) computeCapability: 6.1
# coreClock: 1.531GHz coreCount: 28 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 447.48GiB/s
# 2021-11-17 17:37:27.109899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:05:00.0 name: TITAN X (Pascal) computeCapability: 6.1
# coreClock: 1.531GHz coreCount: 28 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 447.48GiB/s
# 2021-11-17 17:37:27.112396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 2 with properties:
# pciBusID: 0000:84:00.0 name: TITAN X (Pascal) computeCapability: 6.1
# coreClock: 1.531GHz coreCount: 28 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 447.48GiB/s
# 2021-11-17 17:37:27.114892: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 3 with properties:
# pciBusID: 0000:85:00.0 name: TITAN X (Pascal) computeCapability: 6.1
# coreClock: 1.531GHz coreCount: 28 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 447.48GiB/s
# 2021-11-17 17:37:27.114921: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-17 17:37:27.116748: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-11-17 17:37:27.118406: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-11-17 17:37:27.118704: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-11-17 17:37:27.120454: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-11-17 17:37:27.121252: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-11-17 17:37:27.124509: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-11-17 17:37:27.141740: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0, 1, 2, 3
# 2021-11-17 17:37:27.145453: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-17 17:37:27.183211: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2499780000 Hz
# 2021-11-17 17:37:27.187072: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x560680db2f20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-11-17 17:37:27.187102: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-11-17 17:37:27.844209: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56067fe6e3e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-11-17 17:37:27.844252: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): TITAN X (Pascal), Compute Capability 6.1
# 2021-11-17 17:37:27.844263: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): TITAN X (Pascal), Compute Capability 6.1
# 2021-11-17 17:37:27.844273: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): TITAN X (Pascal), Compute Capability 6.1
# 2021-11-17 17:37:27.844284: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (3): TITAN X (Pascal), Compute Capability 6.1
# 2021-11-17 17:37:27.853580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: TITAN X (Pascal) computeCapability: 6.1
# coreClock: 1.531GHz coreCount: 28 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 447.48GiB/s
# 2021-11-17 17:37:27.855941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:05:00.0 name: TITAN X (Pascal) computeCapability: 6.1
# coreClock: 1.531GHz coreCount: 28 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 447.48GiB/s
# 2021-11-17 17:37:27.857509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 2 with properties:
# pciBusID: 0000:84:00.0 name: TITAN X (Pascal) computeCapability: 6.1
# coreClock: 1.531GHz coreCount: 28 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 447.48GiB/s
# 2021-11-17 17:37:27.859077: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 3 with properties:
# pciBusID: 0000:85:00.0 name: TITAN X (Pascal) computeCapability: 6.1
# coreClock: 1.531GHz coreCount: 28 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 447.48GiB/s
# 2021-11-17 17:37:27.859120: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-17 17:37:27.859165: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-11-17 17:37:27.859186: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-11-17 17:37:27.859206: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-11-17 17:37:27.859225: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-11-17 17:37:27.859244: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-11-17 17:37:27.859267: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-11-17 17:37:27.871532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0, 1, 2, 3
# 2021-11-17 17:37:27.871573: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-17 17:37:30.378098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-17 17:37:30.378139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0 1 2 3
# 2021-11-17 17:37:30.378145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N Y N N
# 2021-11-17 17:37:30.378149: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 1:   Y N N N
# 2021-11-17 17:37:30.378153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 2:   N N N Y
# 2021-11-17 17:37:30.378156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 3:   N N Y N
# 2021-11-17 17:37:30.385514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11220 MB memory) -> physical GPU (device: 0, name: TITAN X (Pascal), pci bus id: 0000:04:00.0, compute capability: 6.1)
# 2021-11-17 17:37:30.387444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 11220 MB memory) -> physical GPU (device: 1, name: TITAN X (Pascal), pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2021-11-17 17:37:30.389253: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 11220 MB memory) -> physical GPU (device: 2, name: TITAN X (Pascal), pci bus id: 0000:84:00.0, compute capability: 6.1)
# 2021-11-17 17:37:30.391043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 11220 MB memory) -> physical GPU (device: 3, name: TITAN X (Pascal), pci bus id: 0000:85:00.0, compute capability: 6.1)

# %%
build_emo_pred_plus_model(emotion_predictor, max_length, vocab_size)
# Out:
# 2021-11-17 17:37:30.849086: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10

# %%
# create two h5 files
h5py.File("weights/roberta2emo_pred_embedder_ebp_red+.h5", "w")
h5py.File("weights/roberta2emo_pred_encoder_red+.h5", "w")

print('It works!')
# Out:
# It works!

# %%
emotion_predictor.embedder.save_weights('weights/roberta2emo_pred_embedder_ebp_red+.h5')
emotion_predictor.encoder.save_weights('weights/roberta2emo_pred_encoder_red+.h5')

# %% [markdown]
# # Load the Pre-trained RoBERTa Model

# %%
import os
import h5py
import torch
import numpy as np

# %%
from pytorch_transformers import RobertaTokenizer, RobertaModel

# %%
roberta = RobertaModel.from_pretrained('roberta-base')

# %%
print(roberta)
# Out:
# RobertaModel(
#   (embeddings): RobertaEmbeddings(
#     (word_embeddings): Embedding(50265, 768, padding_idx=0)
#     (position_embeddings): Embedding(514, 768)
#     (token_type_embeddings): Embedding(1, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
# Print model's state_dict
print("Model's state_dict:")
for param_tensor in roberta.state_dict():
    print(param_tensor, '\t', roberta.state_dict()[param_tensor].size())
# Out:
# Model's state_dict:
# embeddings.word_embeddings.weight 	 torch.Size([50265, 768])
# embeddings.position_embeddings.weight 	 torch.Size([514, 768])
# embeddings.token_type_embeddings.weight 	 torch.Size([1, 768])
# embeddings.LayerNorm.weight 	 torch.Size([768])
# embeddings.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.0.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.0.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.0.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.0.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.0.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.0.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.0.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.0.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.0.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.0.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.0.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.0.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.0.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.0.output.dense.bias 	 torch.Size([768])
# encoder.layer.0.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.0.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.1.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.1.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.1.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.1.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.1.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.1.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.1.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.1.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.1.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.1.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.1.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.1.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.1.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.1.output.dense.bias 	 torch.Size([768])
# encoder.layer.1.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.1.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.2.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.2.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.2.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.2.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.2.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.2.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.2.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.2.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.2.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.2.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.2.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.2.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.2.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.2.output.dense.bias 	 torch.Size([768])
# encoder.layer.2.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.2.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.3.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.3.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.3.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.3.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.3.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.3.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.3.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.3.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.3.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.3.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.3.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.3.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.3.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.3.output.dense.bias 	 torch.Size([768])
# encoder.layer.3.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.3.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.4.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.4.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.4.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.4.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.4.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.4.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.4.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.4.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.4.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.4.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.4.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.4.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.4.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.4.output.dense.bias 	 torch.Size([768])
# encoder.layer.4.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.4.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.5.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.5.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.5.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.5.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.5.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.5.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.5.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.5.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.5.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.5.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.5.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.5.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.5.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.5.output.dense.bias 	 torch.Size([768])
# encoder.layer.5.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.5.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.6.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.6.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.6.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.6.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.6.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.6.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.6.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.6.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.6.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.6.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.6.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.6.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.6.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.6.output.dense.bias 	 torch.Size([768])
# encoder.layer.6.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.6.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.7.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.7.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.7.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.7.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.7.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.7.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.7.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.7.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.7.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.7.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.7.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.7.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.7.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.7.output.dense.bias 	 torch.Size([768])
# encoder.layer.7.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.7.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.8.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.8.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.8.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.8.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.8.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.8.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.8.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.8.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.8.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.8.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.8.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.8.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.8.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.8.output.dense.bias 	 torch.Size([768])
# encoder.layer.8.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.8.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.9.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.9.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.9.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.9.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.9.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.9.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.9.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.9.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.9.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.9.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.9.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.9.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.9.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.9.output.dense.bias 	 torch.Size([768])
# encoder.layer.9.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.9.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.10.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.10.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.10.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.10.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.10.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.10.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.10.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.10.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.10.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.10.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.10.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.10.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.10.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.10.output.dense.bias 	 torch.Size([768])
# encoder.layer.10.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.10.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.11.attention.self.query.weight 	 torch.Size([768, 768])
# encoder.layer.11.attention.self.query.bias 	 torch.Size([768])
# encoder.layer.11.attention.self.key.weight 	 torch.Size([768, 768])
# encoder.layer.11.attention.self.key.bias 	 torch.Size([768])
# encoder.layer.11.attention.self.value.weight 	 torch.Size([768, 768])
# encoder.layer.11.attention.self.value.bias 	 torch.Size([768])
# encoder.layer.11.attention.output.dense.weight 	 torch.Size([768, 768])
# encoder.layer.11.attention.output.dense.bias 	 torch.Size([768])
# encoder.layer.11.attention.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.11.attention.output.LayerNorm.bias 	 torch.Size([768])
# encoder.layer.11.intermediate.dense.weight 	 torch.Size([3072, 768])
# encoder.layer.11.intermediate.dense.bias 	 torch.Size([3072])
# encoder.layer.11.output.dense.weight 	 torch.Size([768, 3072])
# encoder.layer.11.output.dense.bias 	 torch.Size([768])
# encoder.layer.11.output.LayerNorm.weight 	 torch.Size([768])
# encoder.layer.11.output.LayerNorm.bias 	 torch.Size([768])
# pooler.dense.weight 	 torch.Size([768, 768])
# pooler.dense.bias 	 torch.Size([768])

# %%
roberta.state_dict()['encoder.layer.0.attention.self.query.bias'].numpy().dtype
# Out:
# dtype('float32')

# %%
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
print(tokenizer.vocab_size)
# Out:
# 50265

# %%
tokenizer.encode('</s>')
# Out:
# [2]

# %%
tokenizer.encode('<s>')
# Out:
# [0]

# %%
tokenizer.encode('<s> How are you doing? </s> </s> I am fine. </s>')
# Out:
# [0, 1336, 32, 47, 608, 116, 2, 2, 38, 524, 2051, 4, 2]

# %%
tokenizer.encode('How are you doing?', 'I am fine.', add_special_tokens = True)
# Out:
# [0, 1336, 32, 47, 608, 116, 2, 2, 38, 524, 2051, 4, 2]

# %%
print(tokenizer.encode('How are you doing?'))
print(tokenizer.encode('I am fine.'))
print(tokenizer.encode('How are you doing? I am fine.'))
# Out:
# [1336, 32, 47, 608, 116]
# [38, 524, 2051, 4]
# [1336, 32, 47, 608, 116, 38, 524, 2051, 4]

# %% [markdown]
# # Initialize Encoder Weights

# %% [markdown]
# ### Load the Emotion Predictor Encoder Weights in .h5 Format

# %%
f = h5py.File('weights/roberta2emo_pred_encoder_red+.h5', 'r+')

# %%
trainable_params = []

def find_params(name):
    if isinstance(f[name], h5py._hl.dataset.Dataset):
        trainable_params.append(name)

f.visit(find_params)

# %%
for param in trainable_params:
    print(param, f[param].shape)
# Out:
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/layernorm_1/beta:0 (768,)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/layernorm_1/gamma:0 (768,)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/layernorm_2/beta:0 (768,)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/layernorm_2/gamma:0 (768,)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/key/bias:0 (768,)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/query/bias:0 (768,)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/value/bias:0 (768,)
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_00/ff_hidden/bias:0 (3072,)
# encoder_layer_00/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_00/ff_output/bias:0 (768,)
# encoder_layer_00/ff_output/kernel:0 (3072, 768)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/layernorm_1/beta:0 (768,)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/layernorm_1/gamma:0 (768,)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/layernorm_2/beta:0 (768,)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/layernorm_2/gamma:0 (768,)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/key/bias:0 (768,)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/query/bias:0 (768,)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/value/bias:0 (768,)
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_01/ff_hidden/bias:0 (3072,)
# encoder_layer_01/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_01/ff_output/bias:0 (768,)
# encoder_layer_01/ff_output/kernel:0 (3072, 768)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/layernorm_1/beta:0 (768,)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/layernorm_1/gamma:0 (768,)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/layernorm_2/beta:0 (768,)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/layernorm_2/gamma:0 (768,)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/key/bias:0 (768,)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/query/bias:0 (768,)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/value/bias:0 (768,)
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_02/ff_hidden/bias:0 (3072,)
# encoder_layer_02/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_02/ff_output/bias:0 (768,)
# encoder_layer_02/ff_output/kernel:0 (3072, 768)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/layernorm_1/beta:0 (768,)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/layernorm_1/gamma:0 (768,)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/layernorm_2/beta:0 (768,)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/layernorm_2/gamma:0 (768,)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/key/bias:0 (768,)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/query/bias:0 (768,)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/value/bias:0 (768,)
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_03/ff_hidden/bias:0 (3072,)
# encoder_layer_03/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_03/ff_output/bias:0 (768,)
# encoder_layer_03/ff_output/kernel:0 (3072, 768)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/layernorm_1/beta:0 (768,)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/layernorm_1/gamma:0 (768,)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/layernorm_2/beta:0 (768,)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/layernorm_2/gamma:0 (768,)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/key/bias:0 (768,)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/query/bias:0 (768,)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/value/bias:0 (768,)
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_04/ff_hidden/bias:0 (3072,)
# encoder_layer_04/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_04/ff_output/bias:0 (768,)
# encoder_layer_04/ff_output/kernel:0 (3072, 768)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/layernorm_1/beta:0 (768,)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/layernorm_1/gamma:0 (768,)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/layernorm_2/beta:0 (768,)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/layernorm_2/gamma:0 (768,)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/key/bias:0 (768,)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/query/bias:0 (768,)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/value/bias:0 (768,)
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_05/ff_hidden/bias:0 (3072,)
# encoder_layer_05/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_05/ff_output/bias:0 (768,)
# encoder_layer_05/ff_output/kernel:0 (3072, 768)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/layernorm_1/beta:0 (768,)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/layernorm_1/gamma:0 (768,)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/layernorm_2/beta:0 (768,)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/layernorm_2/gamma:0 (768,)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/key/bias:0 (768,)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/query/bias:0 (768,)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/value/bias:0 (768,)
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_06/ff_hidden/bias:0 (3072,)
# encoder_layer_06/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_06/ff_output/bias:0 (768,)
# encoder_layer_06/ff_output/kernel:0 (3072, 768)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/layernorm_1/beta:0 (768,)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/layernorm_1/gamma:0 (768,)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/layernorm_2/beta:0 (768,)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/layernorm_2/gamma:0 (768,)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/key/bias:0 (768,)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/query/bias:0 (768,)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/value/bias:0 (768,)
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_07/ff_hidden/bias:0 (3072,)
# encoder_layer_07/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_07/ff_output/bias:0 (768,)
# encoder_layer_07/ff_output/kernel:0 (3072, 768)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/layernorm_1/beta:0 (768,)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/layernorm_1/gamma:0 (768,)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/layernorm_2/beta:0 (768,)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/layernorm_2/gamma:0 (768,)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/key/bias:0 (768,)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/query/bias:0 (768,)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/value/bias:0 (768,)
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_08/ff_hidden/bias:0 (3072,)
# encoder_layer_08/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_08/ff_output/bias:0 (768,)
# encoder_layer_08/ff_output/kernel:0 (3072, 768)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/layernorm_1/beta:0 (768,)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/layernorm_1/gamma:0 (768,)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/layernorm_2/beta:0 (768,)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/layernorm_2/gamma:0 (768,)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/key/bias:0 (768,)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/query/bias:0 (768,)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/value/bias:0 (768,)
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_09/ff_hidden/bias:0 (3072,)
# encoder_layer_09/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_09/ff_output/bias:0 (768,)
# encoder_layer_09/ff_output/kernel:0 (3072, 768)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/layernorm_1/beta:0 (768,)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/layernorm_1/gamma:0 (768,)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/layernorm_2/beta:0 (768,)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/layernorm_2/gamma:0 (768,)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/key/bias:0 (768,)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/query/bias:0 (768,)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/value/bias:0 (768,)
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_10/ff_hidden/bias:0 (3072,)
# encoder_layer_10/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_10/ff_output/bias:0 (768,)
# encoder_layer_10/ff_output/kernel:0 (3072, 768)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/layernorm_1/beta:0 (768,)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/layernorm_1/gamma:0 (768,)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/layernorm_2/beta:0 (768,)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/layernorm_2/gamma:0 (768,)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/key/bias:0 (768,)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/key/kernel:0 (768, 768)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/mha_output/bias:0 (768,)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/mha_output/kernel:0 (768, 768)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/query/bias:0 (768,)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/query/kernel:0 (768, 768)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/value/bias:0 (768,)
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/value/kernel:0 (768, 768)
# encoder_layer_11/ff_hidden/bias:0 (3072,)
# encoder_layer_11/ff_hidden/kernel:0 (768, 3072)
# encoder_layer_11/ff_output/bias:0 (768,)
# encoder_layer_11/ff_output/kernel:0 (3072, 768)

# %% [markdown]
# ### Build the Encoder Mapping Dictionary

# %%
encoder_mapper = {}  # From tf to pytorch
for param in roberta.state_dict():
    if param.startswith('encoder.layer'):
        pt_keywords = param.split('.')
        layer_num = int(pt_keywords[2])
        pt_prefix = '.'.join(pt_keywords[:3]) + '.'
        # beware of the folder name: emotion_predictor_plus if using meed2+ else emotion_predictor
        tf_prefix = 'encoder_layer_{:02d}/emotion_predictor_plus/plain_encoder/encoder_layer_{:02d}/'.format(layer_num, layer_num) 
        tf_prefix_alt = 'encoder_layer_{:02d}/'.format(layer_num)
        encoder_mapper[tf_prefix_alt + 'ff_hidden/bias:0'] = pt_prefix + 'intermediate.dense.bias'
        encoder_mapper[tf_prefix_alt + 'ff_hidden/kernel:0'] = pt_prefix + 'intermediate.dense.weight'
        encoder_mapper[tf_prefix_alt + 'ff_output/bias:0'] = pt_prefix + 'output.dense.bias'
        encoder_mapper[tf_prefix_alt + 'ff_output/kernel:0'] = pt_prefix + 'output.dense.weight'
        encoder_mapper[tf_prefix + 'layernorm_1/beta:0'] = pt_prefix + 'attention.output.LayerNorm.bias'
        encoder_mapper[tf_prefix + 'layernorm_1/gamma:0'] = pt_prefix + 'attention.output.LayerNorm.weight'
        encoder_mapper[tf_prefix + 'layernorm_2/beta:0'] = pt_prefix + 'output.LayerNorm.bias'
        encoder_mapper[tf_prefix + 'layernorm_2/gamma:0'] = pt_prefix + 'output.LayerNorm.weight'
        encoder_mapper[tf_prefix + 'multi_head_attention/key/bias:0'] = pt_prefix + 'attention.self.key.bias'
        encoder_mapper[tf_prefix + 'multi_head_attention/key/kernel:0'] = pt_prefix + 'attention.self.key.weight'
        encoder_mapper[tf_prefix + 'multi_head_attention/mha_output/bias:0'] = pt_prefix + 'attention.output.dense.bias'
        encoder_mapper[tf_prefix + 'multi_head_attention/mha_output/kernel:0'] = pt_prefix + 'attention.output.dense.weight'
        encoder_mapper[tf_prefix + 'multi_head_attention/query/bias:0'] = pt_prefix + 'attention.self.query.bias'
        encoder_mapper[tf_prefix + 'multi_head_attention/query/kernel:0'] = pt_prefix + 'attention.self.query.weight'
        encoder_mapper[tf_prefix + 'multi_head_attention/value/bias:0'] = pt_prefix + 'attention.self.value.bias'
        encoder_mapper[tf_prefix + 'multi_head_attention/value/kernel:0'] = pt_prefix + 'attention.self.value.weight'

# %%
for k, v in encoder_mapper.items():
    print(k)
    print('  ->', v)
# Out:
# encoder_layer_00/ff_hidden/bias:0
#   -> encoder.layer.0.intermediate.dense.bias
# encoder_layer_00/ff_hidden/kernel:0
#   -> encoder.layer.0.intermediate.dense.weight
# encoder_layer_00/ff_output/bias:0
#   -> encoder.layer.0.output.dense.bias
# encoder_layer_00/ff_output/kernel:0
#   -> encoder.layer.0.output.dense.weight
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/layernorm_1/beta:0
#   -> encoder.layer.0.attention.output.LayerNorm.bias
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/layernorm_1/gamma:0
#   -> encoder.layer.0.attention.output.LayerNorm.weight
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/layernorm_2/beta:0
#   -> encoder.layer.0.output.LayerNorm.bias
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/layernorm_2/gamma:0
#   -> encoder.layer.0.output.LayerNorm.weight
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/key/bias:0
#   -> encoder.layer.0.attention.self.key.bias
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/key/kernel:0
#   -> encoder.layer.0.attention.self.key.weight
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.0.attention.output.dense.bias
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.0.attention.output.dense.weight
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/query/bias:0
#   -> encoder.layer.0.attention.self.query.bias
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/query/kernel:0
#   -> encoder.layer.0.attention.self.query.weight
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/value/bias:0
#   -> encoder.layer.0.attention.self.value.bias
# encoder_layer_00/emotion_predictor_plus/plain_encoder/encoder_layer_00/multi_head_attention/value/kernel:0
#   -> encoder.layer.0.attention.self.value.weight
# encoder_layer_01/ff_hidden/bias:0
#   -> encoder.layer.1.intermediate.dense.bias
# encoder_layer_01/ff_hidden/kernel:0
#   -> encoder.layer.1.intermediate.dense.weight
# encoder_layer_01/ff_output/bias:0
#   -> encoder.layer.1.output.dense.bias
# encoder_layer_01/ff_output/kernel:0
#   -> encoder.layer.1.output.dense.weight
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/layernorm_1/beta:0
#   -> encoder.layer.1.attention.output.LayerNorm.bias
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/layernorm_1/gamma:0
#   -> encoder.layer.1.attention.output.LayerNorm.weight
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/layernorm_2/beta:0
#   -> encoder.layer.1.output.LayerNorm.bias
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/layernorm_2/gamma:0
#   -> encoder.layer.1.output.LayerNorm.weight
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/key/bias:0
#   -> encoder.layer.1.attention.self.key.bias
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/key/kernel:0
#   -> encoder.layer.1.attention.self.key.weight
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.1.attention.output.dense.bias
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.1.attention.output.dense.weight
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/query/bias:0
#   -> encoder.layer.1.attention.self.query.bias
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/query/kernel:0
#   -> encoder.layer.1.attention.self.query.weight
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/value/bias:0
#   -> encoder.layer.1.attention.self.value.bias
# encoder_layer_01/emotion_predictor_plus/plain_encoder/encoder_layer_01/multi_head_attention/value/kernel:0
#   -> encoder.layer.1.attention.self.value.weight
# encoder_layer_02/ff_hidden/bias:0
#   -> encoder.layer.2.intermediate.dense.bias
# encoder_layer_02/ff_hidden/kernel:0
#   -> encoder.layer.2.intermediate.dense.weight
# encoder_layer_02/ff_output/bias:0
#   -> encoder.layer.2.output.dense.bias
# encoder_layer_02/ff_output/kernel:0
#   -> encoder.layer.2.output.dense.weight
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/layernorm_1/beta:0
#   -> encoder.layer.2.attention.output.LayerNorm.bias
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/layernorm_1/gamma:0
#   -> encoder.layer.2.attention.output.LayerNorm.weight
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/layernorm_2/beta:0
#   -> encoder.layer.2.output.LayerNorm.bias
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/layernorm_2/gamma:0
#   -> encoder.layer.2.output.LayerNorm.weight
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/key/bias:0
#   -> encoder.layer.2.attention.self.key.bias
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/key/kernel:0
#   -> encoder.layer.2.attention.self.key.weight
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.2.attention.output.dense.bias
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.2.attention.output.dense.weight
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/query/bias:0
#   -> encoder.layer.2.attention.self.query.bias
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/query/kernel:0
#   -> encoder.layer.2.attention.self.query.weight
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/value/bias:0
#   -> encoder.layer.2.attention.self.value.bias
# encoder_layer_02/emotion_predictor_plus/plain_encoder/encoder_layer_02/multi_head_attention/value/kernel:0
#   -> encoder.layer.2.attention.self.value.weight
# encoder_layer_03/ff_hidden/bias:0
#   -> encoder.layer.3.intermediate.dense.bias
# encoder_layer_03/ff_hidden/kernel:0
#   -> encoder.layer.3.intermediate.dense.weight
# encoder_layer_03/ff_output/bias:0
#   -> encoder.layer.3.output.dense.bias
# encoder_layer_03/ff_output/kernel:0
#   -> encoder.layer.3.output.dense.weight
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/layernorm_1/beta:0
#   -> encoder.layer.3.attention.output.LayerNorm.bias
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/layernorm_1/gamma:0
#   -> encoder.layer.3.attention.output.LayerNorm.weight
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/layernorm_2/beta:0
#   -> encoder.layer.3.output.LayerNorm.bias
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/layernorm_2/gamma:0
#   -> encoder.layer.3.output.LayerNorm.weight
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/key/bias:0
#   -> encoder.layer.3.attention.self.key.bias
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/key/kernel:0
#   -> encoder.layer.3.attention.self.key.weight
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.3.attention.output.dense.bias
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.3.attention.output.dense.weight
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/query/bias:0
#   -> encoder.layer.3.attention.self.query.bias
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/query/kernel:0
#   -> encoder.layer.3.attention.self.query.weight
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/value/bias:0
#   -> encoder.layer.3.attention.self.value.bias
# encoder_layer_03/emotion_predictor_plus/plain_encoder/encoder_layer_03/multi_head_attention/value/kernel:0
#   -> encoder.layer.3.attention.self.value.weight
# encoder_layer_04/ff_hidden/bias:0
#   -> encoder.layer.4.intermediate.dense.bias
# encoder_layer_04/ff_hidden/kernel:0
#   -> encoder.layer.4.intermediate.dense.weight
# encoder_layer_04/ff_output/bias:0
#   -> encoder.layer.4.output.dense.bias
# encoder_layer_04/ff_output/kernel:0
#   -> encoder.layer.4.output.dense.weight
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/layernorm_1/beta:0
#   -> encoder.layer.4.attention.output.LayerNorm.bias
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/layernorm_1/gamma:0
#   -> encoder.layer.4.attention.output.LayerNorm.weight
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/layernorm_2/beta:0
#   -> encoder.layer.4.output.LayerNorm.bias
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/layernorm_2/gamma:0
#   -> encoder.layer.4.output.LayerNorm.weight
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/key/bias:0
#   -> encoder.layer.4.attention.self.key.bias
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/key/kernel:0
#   -> encoder.layer.4.attention.self.key.weight
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.4.attention.output.dense.bias
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.4.attention.output.dense.weight
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/query/bias:0
#   -> encoder.layer.4.attention.self.query.bias
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/query/kernel:0
#   -> encoder.layer.4.attention.self.query.weight
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/value/bias:0
#   -> encoder.layer.4.attention.self.value.bias
# encoder_layer_04/emotion_predictor_plus/plain_encoder/encoder_layer_04/multi_head_attention/value/kernel:0
#   -> encoder.layer.4.attention.self.value.weight
# encoder_layer_05/ff_hidden/bias:0
#   -> encoder.layer.5.intermediate.dense.bias
# encoder_layer_05/ff_hidden/kernel:0
#   -> encoder.layer.5.intermediate.dense.weight
# encoder_layer_05/ff_output/bias:0
#   -> encoder.layer.5.output.dense.bias
# encoder_layer_05/ff_output/kernel:0
#   -> encoder.layer.5.output.dense.weight
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/layernorm_1/beta:0
#   -> encoder.layer.5.attention.output.LayerNorm.bias
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/layernorm_1/gamma:0
#   -> encoder.layer.5.attention.output.LayerNorm.weight
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/layernorm_2/beta:0
#   -> encoder.layer.5.output.LayerNorm.bias
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/layernorm_2/gamma:0
#   -> encoder.layer.5.output.LayerNorm.weight
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/key/bias:0
#   -> encoder.layer.5.attention.self.key.bias
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/key/kernel:0
#   -> encoder.layer.5.attention.self.key.weight
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.5.attention.output.dense.bias
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.5.attention.output.dense.weight
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/query/bias:0
#   -> encoder.layer.5.attention.self.query.bias
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/query/kernel:0
#   -> encoder.layer.5.attention.self.query.weight
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/value/bias:0
#   -> encoder.layer.5.attention.self.value.bias
# encoder_layer_05/emotion_predictor_plus/plain_encoder/encoder_layer_05/multi_head_attention/value/kernel:0
#   -> encoder.layer.5.attention.self.value.weight
# encoder_layer_06/ff_hidden/bias:0
#   -> encoder.layer.6.intermediate.dense.bias
# encoder_layer_06/ff_hidden/kernel:0
#   -> encoder.layer.6.intermediate.dense.weight
# encoder_layer_06/ff_output/bias:0
#   -> encoder.layer.6.output.dense.bias
# encoder_layer_06/ff_output/kernel:0
#   -> encoder.layer.6.output.dense.weight
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/layernorm_1/beta:0
#   -> encoder.layer.6.attention.output.LayerNorm.bias
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/layernorm_1/gamma:0
#   -> encoder.layer.6.attention.output.LayerNorm.weight
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/layernorm_2/beta:0
#   -> encoder.layer.6.output.LayerNorm.bias
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/layernorm_2/gamma:0
#   -> encoder.layer.6.output.LayerNorm.weight
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/key/bias:0
#   -> encoder.layer.6.attention.self.key.bias
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/key/kernel:0
#   -> encoder.layer.6.attention.self.key.weight
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.6.attention.output.dense.bias
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.6.attention.output.dense.weight
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/query/bias:0
#   -> encoder.layer.6.attention.self.query.bias
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/query/kernel:0
#   -> encoder.layer.6.attention.self.query.weight
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/value/bias:0
#   -> encoder.layer.6.attention.self.value.bias
# encoder_layer_06/emotion_predictor_plus/plain_encoder/encoder_layer_06/multi_head_attention/value/kernel:0
#   -> encoder.layer.6.attention.self.value.weight
# encoder_layer_07/ff_hidden/bias:0
#   -> encoder.layer.7.intermediate.dense.bias
# encoder_layer_07/ff_hidden/kernel:0
#   -> encoder.layer.7.intermediate.dense.weight
# encoder_layer_07/ff_output/bias:0
#   -> encoder.layer.7.output.dense.bias
# encoder_layer_07/ff_output/kernel:0
#   -> encoder.layer.7.output.dense.weight
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/layernorm_1/beta:0
#   -> encoder.layer.7.attention.output.LayerNorm.bias
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/layernorm_1/gamma:0
#   -> encoder.layer.7.attention.output.LayerNorm.weight
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/layernorm_2/beta:0
#   -> encoder.layer.7.output.LayerNorm.bias
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/layernorm_2/gamma:0
#   -> encoder.layer.7.output.LayerNorm.weight
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/key/bias:0
#   -> encoder.layer.7.attention.self.key.bias
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/key/kernel:0
#   -> encoder.layer.7.attention.self.key.weight
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.7.attention.output.dense.bias
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.7.attention.output.dense.weight
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/query/bias:0
#   -> encoder.layer.7.attention.self.query.bias
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/query/kernel:0
#   -> encoder.layer.7.attention.self.query.weight
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/value/bias:0
#   -> encoder.layer.7.attention.self.value.bias
# encoder_layer_07/emotion_predictor_plus/plain_encoder/encoder_layer_07/multi_head_attention/value/kernel:0
#   -> encoder.layer.7.attention.self.value.weight
# encoder_layer_08/ff_hidden/bias:0
#   -> encoder.layer.8.intermediate.dense.bias
# encoder_layer_08/ff_hidden/kernel:0
#   -> encoder.layer.8.intermediate.dense.weight
# encoder_layer_08/ff_output/bias:0
#   -> encoder.layer.8.output.dense.bias
# encoder_layer_08/ff_output/kernel:0
#   -> encoder.layer.8.output.dense.weight
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/layernorm_1/beta:0
#   -> encoder.layer.8.attention.output.LayerNorm.bias
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/layernorm_1/gamma:0
#   -> encoder.layer.8.attention.output.LayerNorm.weight
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/layernorm_2/beta:0
#   -> encoder.layer.8.output.LayerNorm.bias
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/layernorm_2/gamma:0
#   -> encoder.layer.8.output.LayerNorm.weight
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/key/bias:0
#   -> encoder.layer.8.attention.self.key.bias
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/key/kernel:0
#   -> encoder.layer.8.attention.self.key.weight
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.8.attention.output.dense.bias
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.8.attention.output.dense.weight
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/query/bias:0
#   -> encoder.layer.8.attention.self.query.bias
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/query/kernel:0
#   -> encoder.layer.8.attention.self.query.weight
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/value/bias:0
#   -> encoder.layer.8.attention.self.value.bias
# encoder_layer_08/emotion_predictor_plus/plain_encoder/encoder_layer_08/multi_head_attention/value/kernel:0
#   -> encoder.layer.8.attention.self.value.weight
# encoder_layer_09/ff_hidden/bias:0
#   -> encoder.layer.9.intermediate.dense.bias
# encoder_layer_09/ff_hidden/kernel:0
#   -> encoder.layer.9.intermediate.dense.weight
# encoder_layer_09/ff_output/bias:0
#   -> encoder.layer.9.output.dense.bias
# encoder_layer_09/ff_output/kernel:0
#   -> encoder.layer.9.output.dense.weight
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/layernorm_1/beta:0
#   -> encoder.layer.9.attention.output.LayerNorm.bias
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/layernorm_1/gamma:0
#   -> encoder.layer.9.attention.output.LayerNorm.weight
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/layernorm_2/beta:0
#   -> encoder.layer.9.output.LayerNorm.bias
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/layernorm_2/gamma:0
#   -> encoder.layer.9.output.LayerNorm.weight
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/key/bias:0
#   -> encoder.layer.9.attention.self.key.bias
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/key/kernel:0
#   -> encoder.layer.9.attention.self.key.weight
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.9.attention.output.dense.bias
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.9.attention.output.dense.weight
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/query/bias:0
#   -> encoder.layer.9.attention.self.query.bias
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/query/kernel:0
#   -> encoder.layer.9.attention.self.query.weight
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/value/bias:0
#   -> encoder.layer.9.attention.self.value.bias
# encoder_layer_09/emotion_predictor_plus/plain_encoder/encoder_layer_09/multi_head_attention/value/kernel:0
#   -> encoder.layer.9.attention.self.value.weight
# encoder_layer_10/ff_hidden/bias:0
#   -> encoder.layer.10.intermediate.dense.bias
# encoder_layer_10/ff_hidden/kernel:0
#   -> encoder.layer.10.intermediate.dense.weight
# encoder_layer_10/ff_output/bias:0
#   -> encoder.layer.10.output.dense.bias
# encoder_layer_10/ff_output/kernel:0
#   -> encoder.layer.10.output.dense.weight
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/layernorm_1/beta:0
#   -> encoder.layer.10.attention.output.LayerNorm.bias
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/layernorm_1/gamma:0
#   -> encoder.layer.10.attention.output.LayerNorm.weight
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/layernorm_2/beta:0
#   -> encoder.layer.10.output.LayerNorm.bias
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/layernorm_2/gamma:0
#   -> encoder.layer.10.output.LayerNorm.weight
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/key/bias:0
#   -> encoder.layer.10.attention.self.key.bias
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/key/kernel:0
#   -> encoder.layer.10.attention.self.key.weight
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.10.attention.output.dense.bias
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.10.attention.output.dense.weight
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/query/bias:0
#   -> encoder.layer.10.attention.self.query.bias
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/query/kernel:0
#   -> encoder.layer.10.attention.self.query.weight
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/value/bias:0
#   -> encoder.layer.10.attention.self.value.bias
# encoder_layer_10/emotion_predictor_plus/plain_encoder/encoder_layer_10/multi_head_attention/value/kernel:0
#   -> encoder.layer.10.attention.self.value.weight
# encoder_layer_11/ff_hidden/bias:0
#   -> encoder.layer.11.intermediate.dense.bias
# encoder_layer_11/ff_hidden/kernel:0
#   -> encoder.layer.11.intermediate.dense.weight
# encoder_layer_11/ff_output/bias:0
#   -> encoder.layer.11.output.dense.bias
# encoder_layer_11/ff_output/kernel:0
#   -> encoder.layer.11.output.dense.weight
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/layernorm_1/beta:0
#   -> encoder.layer.11.attention.output.LayerNorm.bias
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/layernorm_1/gamma:0
#   -> encoder.layer.11.attention.output.LayerNorm.weight
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/layernorm_2/beta:0
#   -> encoder.layer.11.output.LayerNorm.bias
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/layernorm_2/gamma:0
#   -> encoder.layer.11.output.LayerNorm.weight
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/key/bias:0
#   -> encoder.layer.11.attention.self.key.bias
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/key/kernel:0
#   -> encoder.layer.11.attention.self.key.weight
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/mha_output/bias:0
#   -> encoder.layer.11.attention.output.dense.bias
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/mha_output/kernel:0
#   -> encoder.layer.11.attention.output.dense.weight
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/query/bias:0
#   -> encoder.layer.11.attention.self.query.bias
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/query/kernel:0
#   -> encoder.layer.11.attention.self.query.weight
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/value/bias:0
#   -> encoder.layer.11.attention.self.value.bias
# encoder_layer_11/emotion_predictor_plus/plain_encoder/encoder_layer_11/multi_head_attention/value/kernel:0
#   -> encoder.layer.11.attention.self.value.weight

# %% [markdown]
# ### Write to the Emotion Predictor Encoder .h5 File

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['encoder_layer_00', 'encoder_layer_01', 'encoder_layer_02', 'encoder_layer_03', 'encoder_layer_04', 'encoder_layer_05', 'encoder_layer_06', 'encoder_layer_07', 'encoder_layer_08', 'encoder_layer_09', 'encoder_layer_10', 'encoder_layer_11']>

# %%
for k, v in encoder_mapper.items():
    if len(f[k].shape) < 2:
        f[k][()] = roberta.state_dict()[v].numpy()
    else:
        f[k][()] = roberta.state_dict()[v].numpy().T

# %%
f.close()

# %% [markdown]
# ### Check Equivalence

# %%
f = h5py.File('weights/roberta2emo_pred_encoder_red+.h5', 'r')

# %%
all_close = True
for k, v in encoder_mapper.items():
    if len(f[k].shape) < 2:
        if not np.allclose(f[k][()], roberta.state_dict()[v].numpy()):
            all_close = False
    else:
        if not np.allclose(f[k][()], roberta.state_dict()[v].numpy().T):
            all_close = False
print(all_close)
# Out:
# True

# %%
f.close()

# %% [markdown]
# # Initialize Embedder Weights

# %% [markdown]
# ### Load the Emotion Predictor Embedder Weights in .h5 Format

# %%
f = h5py.File('weights/roberta2emo_pred_embedder_ebp_red+.h5', 'r+')

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['comm_embed', 'dropout_embed', 'emot_embed', 'layernorm_embed', 'pos_embed', 'seg_embed', 'word_embed']>

# %%
trainable_params = []

def find_params(name):
    if isinstance(f[name], h5py._hl.dataset.Dataset):
        trainable_params.append(name)

f.visit(find_params)

# %%
for param in trainable_params:
    print(param, f[param].shape)
# Out:
# comm_embed/emotion_predictor_plus/meed_embedder/comm_embed/embeddings:0 (7, 768)
# emot_embed/emotion_predictor_plus/meed_embedder/emot_embed/embeddings:0 (41, 768)
# layernorm_embed/emotion_predictor_plus/meed_embedder/layernorm_embed/beta:0 (768,)
# layernorm_embed/emotion_predictor_plus/meed_embedder/layernorm_embed/gamma:0 (768,)
# pos_embed/emotion_predictor_plus/meed_embedder/pos_embed/embeddings:0 (102, 768)
# seg_embed/emotion_predictor_plus/meed_embedder/seg_embed/embeddings:0 (2, 768)
# word_embed/emotion_predictor_plus/meed_embedder/word_embed/embeddings:0 (50265, 768)

# %% [markdown]
# ### Build the Embedder Mapping Dictionary

# %%
embedder_mapper = {
    'layernorm_embed/emotion_predictor_plus/meed_embedder/layernorm_embed/beta:0': 'embeddings.LayerNorm.bias',
    'layernorm_embed/emotion_predictor_plus/meed_embedder/layernorm_embed/gamma:0': 'embeddings.LayerNorm.weight',
    'word_embed/emotion_predictor_plus/meed_embedder/word_embed/embeddings:0': 'embeddings.word_embeddings.weight'
}

# %% [markdown]
# ### Write to the Emotion Predictor Embedder .h5 File

# %%
for k, v in embedder_mapper.items():
    f[k][()] = roberta.state_dict()[v].numpy()

# %%
k = 'pos_embed/emotion_predictor_plus/meed_embedder/pos_embed/embeddings:0'
v = 'embeddings.position_embeddings.weight'
f[k][()] = roberta.state_dict()[v].numpy()[:102,:]

# %%
f.close()

# %% [markdown]
# ### Check Equivalence

# %%
f = h5py.File('weights/roberta2emo_pred_embedder_ebp_red+.h5', 'r')

# %%
all_close = True
for k, v in embedder_mapper.items():
    if not np.allclose(f[k][()], roberta.state_dict()[v].numpy()):
        all_close = False
print(all_close)
# Out:
# True

# %%
f.close()
